# %% [markdown]
# # Get Dataframe

# %%
import pandas as pd
import pickle

def get_upwork_job_descriptions():
    jobs = pd.read_csv('upwork-jobs.csv')
    # retun a list of the column 'description'
    return jobs['description'].tolist()

def get_fiverr_job_descriptions():
    jobs = pd.read_csv('fiverr.csv')
    # retun a list of the column 'name'
    return jobs['name'].tolist()

def get_fiverr_dictionary():
    dictionary = pickle.load(open('fiverr-dictionary.pkl', 'rb'))
    return dictionary

def get_fiverr_corpus():
    corpus = pickle.load(open('fiverr-corpus.pkl', 'rb'))
    return corpus

def get_upwork_dictionary():
    dictionary = pickle.load(open('upwork-dictionary.pkl', 'rb'))
    return dictionary

def get_upwork_corpus():
    corpus = pickle.load(open('upwork-corpus.pkl', 'rb'))
    return corpus

# %% [markdown]
# # Preprocessing

# %%
import re
import pandas as pd
import spacy
from gensim.models.phrases import Phrases, Phraser
from collections import Counter
from tqdm import tqdm
from gensim.corpora import Dictionary
import pickle


# Load spaCy model
nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])

# Define preprocessing function
def preprocess(text):
    """
    Preprocess a given text by:
    - Lowercasing
    - Removing punctuation
    - Tokenizing
    - Removing stopwords
    - Lemmatizing
    """
    # Lowercase text
    text = text.lower()
    
    # Remove punctuation and numbers
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    
    # Use spaCy for tokenization and lemmatization
    doc = nlp(text)
    words = [token.lemma_ for token in doc if len(token) > 3 and not token.is_stop]
    
    return words

# Define function to create a final bag of words including unigrams and bigrams
def create_bag_of_words(words, bigram_phraser):
    """
    Create a bag of words that includes both unigrams and bigrams.
    """
    words_with_bigrams = words + bigram_phraser[words]
    bag_of_words = Counter(words_with_bigrams)
    return bag_of_words

# Set the sample texts
sample_texts = get_upwork_job_descriptions()  # Assuming this function is defined elsewhere

# Preprocess all sample texts with a progress bar
preprocessed_corpus = [preprocess(text) for text in tqdm(sample_texts)]

print("Preprocessing done")

# Train bigram model on entire corpus
phrases = Phrases(preprocessed_corpus, min_count=30, threshold=30)  # Adjusted for larger corpus size
bigram_phraser = Phraser(phrases)

print("Bigram model trained")

# Process each preprocessed text and create a list of bags of words
lda_ready_corpus = [create_bag_of_words(cleaned_text, bigram_phraser) for cleaned_text in tqdm(preprocessed_corpus)]

print("Corpus created")

# Create a dictionary representation of the documents
dictionary = Dictionary(lda_ready_corpus)

print("Dictionary created")

# Filter out words that occur in less than 5% of the documents or more than 50% of the documents
dictionary.filter_extremes(no_below=.05, no_above=.5)
corpus = [dictionary.doc2bow(doc) for doc in lda_ready_corpus]

print("Corpus filtered")

pickle.dump(corpus, open('upwork-corpus.pkl', 'wb'))
pickle.dump(dictionary, open('upwork-dictionary.pkl', 'wb'))
# Out:
# 100%|██████████| 53058/53058 [08:22<00:00, 105.62it/s]
# Preprocessing done
# Bigram model trained
# 100%|██████████| 53058/53058 [00:02<00:00, 21096.92it/s]
# Corpus created
# Dictionary created
# Corpus filtered

# %% [markdown]
# # LDA Modeling

# %%
from gensim import corpora
from gensim.models import LdaModel
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# Load the preprocessed dictionary
dictionary = get_upwork_dictionary()
corpus = get_upwork_corpus()

# Define and train the LDA model
n_topics = 8  # Number of topics you want to extract
random_state = 42  # Random state for reproducibility
passes = 50  # Number of passes through the corpus

lda_model = LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=n_topics,
    random_state=random_state,
    passes=passes
)

# Prepare the LDA visualization data
lda_vis = gensimvis.prepare(lda_model, corpus, dictionary)

# Display the LDA visualization (for Jupyter Notebooks)
pyLDAvis.display(lda_vis)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=25144) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /opt/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=25144) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /opt/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=25144) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /opt/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=25144) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /opt/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=25144) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /opt/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=25144) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /opt/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=25144) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /opt/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=25144) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /opt/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=25144) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /opt/anaconda3/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=25144) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el25144142748236326447136327" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el25144142748236326447136327_data = {"mdsDat": {"x": [-0.1507121362857922, -0.055925572421848195, -0.1391146477818055, -0.09980216158473827, -0.12889656076160325, 0.045219417300982195, 0.1427425144249894, 0.38648914710981574], "y": [0.07950946921931007, -0.08528288924066561, 0.08793479336558152, -0.006072403087626657, 0.11161519838818086, -0.11734362017701351, -0.26965353075012327, 0.19929298228235698], "topics": [1, 2, 3, 4, 5, 6, 7, 8], "cluster": [1, 1, 1, 1, 1, 1, 1, 1], "Freq": [24.105102897719462, 18.098418293658032, 15.55880114265694, 14.385335651825285, 12.020091087366822, 8.539879818322087, 4.765665297559801, 2.526705810891566]}, "tinfo": {"Term": ["english", "content", "graphic", "locate", "datum", "statesclick", "need", "requirement", "freelancer", "write", "medium", "applycountry", "states", "social", "united", "adobe", "social_medium", "marketing", "design", "united_statesclick", "entry", "creative", "developer", "strategy", "development", "datum_entry", "range", "microsoft", "general", "requirement_freelancer", "organizational", "cold", "appointment", "virtual_assistant", "compensation", "interpersonal", "cold_call", "write_verbal", "salary", "coordinate", "inquiry", "outbound", "organizational_skill", "negotiation", "play_crucial", "pivotal", "recruit", "generationskill", "submit_resume", "supportive", "exceed", "lead_generationskill", "satisfaction", "generationcountry", "lead_generationcountry", "quickbook", "telemarketing", "representative", "leadership", "communicationsskill", "verbal", "thrive", "scheduling", "motivated", "fastpaced", "timely", "resume", "prioritize", "phone_chat", "exceptional", "collaborative", "commitment", "role", "potential", "team_member", "communication", "remote", "opportunity", "position", "dynamic", "excellent", "contribute", "environment", "ensure", "team", "join", "maintain", "industry", "ability", "lead", "individual", "skill", "customer", "support", "identify", "sale", "client", "independently", "seek", "strong", "experience", "service", "manage", "management", "business", "candidate", "prove", "work", "provide", "include", "company", "detail", "range", "ideal", "long_term", "get", "developmentskillsshopify", "website_developmentskillsshopify", "try", "ask", "pretty", "recently", "shopify_template", "likely", "say", "instead", "designcountry_australiaclick", "reason", "happen", "somebody", "basically", "pick", "away", "fix_price", "stop", "right_person", "etchourly", "walk", "etchourly_range", "proceed", "lose", "twitterx", "shopifycountry", "stuff", "thing", "go", "happy", "know", "sure", "feel_free", "have", "certain", "little", "reply", "price", "long", "page", "read", "feel", "show", "like", "person", "free", "term", "come", "want", "site", "landing", "landing_page", "start", "question", "need", "find", "right", "send", "shopify", "website", "people", "time", "help", "look", "united", "united_statesclick", "statesclick", "ecommerce", "range", "product", "work", "example", "wordpress", "hour", "build", "design", "provide", "follow", "create", "complete", "good", "development", "project", "stack", "javascript", "integration", "python", "frontend", "functionality", "userfriendly", "android", "react", "interface", "framework", "programming", "nodejs", "user_interface", "java", "apis", "uiux", "javascriptskill", "javascriptcountry", "apiskill", "mysql", "deploy", "intuitive", "apicountry", "stack_developmentskillsweb", "cssskill", "scalable", "programming_language", "machine_learn", "csscountry", "developer", "backend", "cloud", "html", "integrate", "user", "mobile", "code", "security", "development", "responsive", "server", "system", "application", "implement", "testing", "develop", "problemsolving", "feature", "developmentcountry", "experience", "project", "skilled", "design", "candidate", "range", "strong", "work", "create", "skill", "include", "seek", "look", "united", "ensure", "understanding", "team", "ideal", "adobe", "photoshop", "adobe_photoshop", "illustrat ...
